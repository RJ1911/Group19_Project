# %%
# import pdfplumber
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords 
from string import punctuation
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from heapq import nlargest
from collections import defaultdict
import pandas as pd 
from nltk.collocations import *
import base64,random
import os
import pandas as pd
from pyresparser import ResumeParser
import pdfplumber
import re

# %%
# %%capture

# Define the directory containing resumes
resumes_dir = 'cv_to_df/'
resumes_dir_full_path = os.path.abspath(resumes_dir)

def pdf_to_base64(file_path):
    
    encoded_pdf = base64.b64encode(file_path.read()).decode('utf-8')

    return encoded_pdf

def extract_text_from_pdf(filepath):
    with pdfplumber.open(filepath) as pdf:
        text = ""
        pages = pdf.pages
        for page in pages:
            text += page.extract_text(x_tolerance=2)
    return text

# Create an empty DataFrame object to store the extracted data
df = pd.DataFrame()

# Iterate through all files in the resumes directory
for filename in os.listdir(resumes_dir):
    if filename.endswith('.pdf'):  # Check if the file is a PDF
        # Apply the ResumeParser function to the current file and append the extracted data to the DataFrame
        data = ResumeParser(os.path.join(resumes_dir, filename)).get_extracted_data()
        # Add a new column to the DataFrame containing the file path
        data['file_path'] = os.path.join(resumes_dir, filename)
        # Append the extracted data to the DataFrame
        df = df.append(data, ignore_index=True)
        # df = pd.concat([df, data], ignore_index=True)


# Extract text from all PDFs in the resumes directory and create a new DataFrame
data = []
for filename in os.listdir(resumes_dir):
    if filename.endswith('.pdf'):
        filepath = os.path.join(resumes_dir, filename)
        resume_data = extract_text_from_pdf(filepath)
        data.append({'file_path': filepath, 'All': resume_data})
df2 = pd.DataFrame(data)

# Merge the two data frames on the "file_path" column
merged_df = pd.merge(df, df2, on='file_path')
merged_df.drop(columns=["college_name","company_names","designation","experience","total_experience"], axis=1, inplace=True) # dropping unwanted col

# Define the regex pattern to match unwanted characters
unwanted_chars_pattern = r'[^a-zA-Z !@#$%&*_+-=|\:";<>,./()[\]{}\']'
for col in ['skills','degree', 'All']:
    merged_df[col] = merged_df[col].apply(lambda x: re.sub(unwanted_chars_pattern, '', str(x)))


merged_df
# Out:
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# c:\Users\Dell\miniconda3\envs\myenv\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5036\875813791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
#                                         name                          email  \
# 0                                 AKASH SHAW        akashshawju12@gmail.com
# 1                            AKSHUN KHAJURIA      akshun.khaj2002@gmail.com
# 2                                       None                           None
# 3                             ANURAG KHURANA    anuragkhurana2525@gmail.com
# 4                        Arghadeep Mukherjee  arghadeepischatting@gmail.com
# 5                              ARGHYADIP ROY        agandpian2012@gmail.com
# 6                              Arindam Hazra          arihazra101@gmail.com
# 7                               Arjun Saibya       arjunsaibya001@gmail.com
# 8                              ASHWANI KUMAR    ashwanibhagat2002@gmail.com
# 9                                   AYAN MAL            ayanmal70@gmail.com
# 10                                       y u                           None
# 11                                GREGORY N.           ghoffman@hotmail.com
# 12                           Matthew Winston                   wins@aol.com
# 13                               Patricia L.          prichardson@yahoo.com
# 14                               Craig Novak                 cn336@gnet.com
# 15                               John Dawson             johndaw@gotnet.com
# 16                                William B.               wstrom@yahoo.com
# 17                       Baibhav Karan Singh       baibhavsingh82@gmail.com
# 18                                Tilak Road         avinanda1303@gmail.com
# 19                                Debjit Das      debjit.das.1729@gmail.com
# 20                            EDUCATION B.E.        hemalihansda6@gmail.com
# 21                              HIMESH DUTTA      himeshdutta1512@gmail.com
# 22                      ISHITA BHATTACHARYYA   i.bhattacharyya333@gmail.com
# 23                           Kunal Pramanick   pramanickkunal1999@gmail.com
# 24                            Muhsin Mansoor       muhsinmansoor7@gmail.com
# 25                             Nilarghya Roy     roynilarghya2001@gmail.com
# 26                          Projna Sadhukhan         psadhukhan34@gmail.com
# 27                        Rajan Kumar Mahato     rajan.mahato1253@gmail.com
# 28  https://github.com/rayaanoidPrime G-26/8        rayaanghosh18@gmail.com
# 29                              Avraneel Pal        avraneelpal22@gmail.com
# 30                        BETHUNE COLLEGIATE         iva.teghoria@gmail.com
# 31                               Aritra Saha       aritrasaha0806@gmail.com
# 32                             Deepanjan Das      dasdeepanjan.37@gmail.com
# 33                             MD NASIRUDDIN         mdnasir.suri@gmail.com
# 34                                      None                           None
# 35                                 Rinku Das         dasrinku9901@gmail.com
# 36                           RUDRAPRASAD ROY       royrudra.rpr08@gmail.com
# 37                             Sabnam Laskar       sabnamlaskar26@gmail.com
# 38                                  SAIKAT M     saikatmazumdar18@gmail.com
# 39                             Shilpa Mondal     MONDALSHILPA2112@GMAIL.COM
# 40                        Shlok Jhunjhunwala             shlokjjw@gmail.com
# 41                                Sikha Saha         sikhasaha055@gmail.com
# 42                        Soumyadeep Khamrai    soumyadeepkhamrai@gmail.com
# 43                            RESUME CONTACT   suchismitamondal23@gmail.com
# 44                               Tanvir Alam        tanviralam15p@gmail.com
#
#    mobile_number                                             skills  \
# 0     6290912977  ['Html5', 'Writing', 'System', 'Information te...
# 1     8899692356  ['System', 'Content', 'Email', 'Video', 'Micro...
# 2           None                                                 []
# 3     7889861541  ['System', 'Email', 'Microsoft word', 'Autocad...
# 4     0020112011  ['Video', 'Mechanical engineering', 'Autocad',...
# 5     6297443676  ['Statistics', 'Java', 'Css', 'Python', 'Math'...
# 6     6290374950  ['Lighting', 'System', 'Segmentation', 'Techni...
# 7     9064471045  ['Python', 'Technical', 'Troubleshooting', 'Au...
# 8     9178897841  ['Html', 'Content', 'Website', 'Programming', ...
# 9     8617788562  ['Transport', 'Specifications', 'Testing', 'Sy...
# 10          None                                    ['C', 'P', 'R']
# 11  606.235.7086  ['Inventory', 'Operating systems', 'Accounting...
# 12  772-288-9428  ['Dhcp', 'Finance', 'Servers', 'Transactions',...
# 13      772-3121  ['Consulting', 'Forecasting', 'Industry trends...
# 14      779.0052  ['Consulting', 'Customer service', 'Client ser...
# 15  201.703.1116  ['Forecasting', 'Mvp', 'Accounting', 'R', 'Fin...
# 16  405-672-9785  ['Sql server', 'Customer service', 'Architectu...
# 17   694 8159945  ['Sql', 'Java', 'Css', 'Html', 'Email', 'Try',...
# 18    9073816662  ['Process', 'Java', 'Python', 'System', 'Wifi'...
# 19    6291853074  ['Mechanical engineering', 'Autocad', 'Experim...
# 20    8918838900  ['Email', 'Microsoft excel', 'Microsoft word',...
# 21    8509384431  ['Operating systems', 'Routing', 'Website', 'U...
# 22    0020108011  ['Statistics', 'Python', 'System', 'Technical'...
# 23      021 2021  ['Css', 'Html', 'Email', 'Time management', 'C...
# 24    0020111020  ['Operating systems', 'Instrumentation', 'Webs...
# 25    8918609634  ['Architecture', 'Html', 'Instrumentation', 'P...
# 26    0020108011  ['Forecasting', 'Html', 'Website', 'Programmin...
# 27    9564171299  ['Analyze', 'Technical', 'Design', 'Mechanical...
# 28    7044097137  ['Architecture', 'R', 'Numpy', 'Experimental',...
# 29    9836489177  ['Communication', 'Engineering', 'Interactive'...
# 30    9831050056  ['Mobile', 'Time management', 'Engineering', '...
# 31    6290132537  ['Finance', 'Html', 'Website', 'Matrix', 'Prog...
# 32    9163616660  ['Numpy', 'Hypothesis', 'Electrical engineerin...
# 33    8167715678  ['Html', 'Instrumentation', 'Website', 'Progra...
# 34          None                                    ['P', 'C', 'R']
# 35    8967380679  ['Product quality', 'Analyze', 'Numpy', 'Chemi...
# 36    6289072359  ['Css', 'Api', 'System', 'Html', 'Interactive'...
# 37    8910339399  ['Java', 'Python', 'Css', 'Design', 'Html', 'A...
# 38    8584091792  ['Java', 'Python', 'Css', 'R', 'Technical', 'H...
# 39    8240469560  ['Sql', 'Python', 'Industry trends', 'Technica...
# 40    0020108011  ['Architecture', 'Html', 'Website', 'Communica...
# 41    7439463853  ['Html', 'Instrumentation', 'Video', 'Website'...
# 42    8116893609  ['Operations', 'Protocols', 'System', 'Technic...
# 43    7059321202  ['Python', 'Windows', 'System', 'Technical', '...
# 44          None  ['Html', 'Website', 'Communication', 'Engineer...
#
#                                                degree  no_of_pages  \
# 0   ['WBBSE ( class X )', 'BE in INFORMATION TECHN...            1
# 1                    ['B.E. Mechanical Engineering)']            1
# 2                                                None            1
# 3                                                None            1
# 4                                                None            2
# 5            ['B.E. IN COMPUTER SCIENCE ENGINEERING']            1
# 6                                                None            2
# 7                                                None            1
# 8                   ['B.E in Information Technology']            1
# 9              ['BACHELOR OF MECHANICAL ENGINEERING']            1
# 10                                               None            1
# 11  ['DALLAS BAPTIST UNIVERSITY, Dallas, TX  Bache...            3
# 12                                               None            3
# 13                                               None            5
# 14                                               None            5
# 15                                               None            4
# 16                                               None            4
# 17                        ['Bachelor Of Engineering']            1
# 18  ['Bachelor of Technology', 'Master of Technolo...            2
# 19  ['Mechatronics Training', 'Mechanical Engineer...            1
# 20  ['B.E. in Electronics and Telecommunication', ...            1
# 21  ['Degree / Certificate', 'B.E. nSenior Seconda...            1
# 22  ['Degree / Certificate', 'Bachelor of Engineer...            1
# 23                                               None            1
# 24        ['B.E. in Electronics and Instrumentation']            1
# 25                                               None            1
# 26                                               None            1
# 27                                               None            1
# 28                                               None            1
# 29       ['B.E. in Computer Science and Engineering']            1
# 30                                               None            1
# 31  ['Bachelor of Technology in Electronics and Te...            1
# 32                                               None            2
# 33  ['  B.E. Electronics & Instrumentation Enginee...            1
# 34                                               None            1
# 35       ["B.E. ProdE'24", 'Bachelor of Engineering']            1
# 36       ['B.E. in Computer Science and Engineering']            1
# 37                                               None            1
# 38                                               None            1
# 39                                               None            1
# 40  ['Degree / Certificate', 'Bachelor of Engineer...            1
# 41  ['Bachelor of EngineeringnInstrumentation and ...            1
# 42  ['B.E. Mechanical Engineering', 'DEGREE nBache...            1
# 43                                               None            2
# 44                                               None            1
#
#                                            file_path  \
# 0                     cv_to_df/Akash_Shaw_resume.pdf
# 1                cv_to_df/AKSHUN_KHAJURIA_FTE_CV.pdf
# 2   cv_to_df/AnubhabTripathi_JadavpurUniversity1.pdf
# 3                   cv_to_df/Anurag Khurana_CV-3.pdf
# 4                   cv_to_df/Arghadeep-Mukherjee.pdf
# 5                  cv_to_df/Arghyadip_Roy_resume.pdf
# 6                 cv_to_df/Arindam_Resume - Copy.pdf
# 7                   cv_to_df/Arjun_Saibya Resume.pdf
# 8                  cv_to_df/Ashwani_AirbusResume.pdf
# 9                    cv_to_df/Ayan Mal_CV_AIRBUS.pdf
# 10               cv_to_df/AyushPrakash_CV_Airbus.pdf
# 11                              cv_to_df/ba-ex02.pdf
# 12                              cv_to_df/ba-ex06.pdf
# 13                              cv_to_df/ba-ex10.pdf
# 14                              cv_to_df/ba-ex11.pdf
# 15                              cv_to_df/ba-ex13.pdf
# 16                              cv_to_df/ba-ex16.pdf
# 17           cv_to_df/Baibhav_Karan_Singh_resume.pdf
# 18                          cv_to_df/CV AVINANDA.pdf
# 19                       cv_to_df/Debjit_Das__CV.pdf
# 20                        cv_to_df/hemali_resume.pdf
# 21                  cv_to_df/HIMESH_DUTTA_RESUME.pdf
# 22  cv_to_df/Ishita Bhattacharyya_ Airbus_Resume.pdf
# 23                         cv_to_df/Kunal_Resume.pdf
# 24                       cv_to_df/Muhsin_Mansoor.pdf
# 25                         cv_to_df/NilarghyaRoy.pdf
# 26                     cv_to_df/Projna_Sadhukhan.pdf
# 27                  cv_to_df/RajanKumarMahato_CV.pdf
# 28    cv_to_df/Rayaan_Ghosh_JU_MECH_002011201164.pdf
# 29                  cv_to_df/Resume Avraneel Pal.pdf
# 30               cv_to_df/Resume-Sampreeti(1107).pdf
# 31                    cv_to_df/Resume_AritraSaha.pdf
# 32                     cv_to_df/Resume_Deepanjan.pdf
# 33                cv_to_df/Resume_MD Nasiruddin1.pdf
# 34             cv_to_df/Resume_Sabarno_Biswas_EE.pdf
# 35                         cv_to_df/Rinku_Das_CV.pdf
# 36                cv_to_df/RudraprasadRoy_resume.pdf
# 37                      cv_to_df/Sabnam_s Resume.pdf
# 38                      cv_to_df/Saikat_Mazumdar.pdf
# 39                 cv_to_df/Shilpa Mondal_Resume.pdf
# 40     cv_to_df/Shlok Jhunjhunwala RESUME latest.pdf
# 41                    cv_to_df/sikha_saha_resume.pdf
# 42            cv_to_df/Soumyadeep Khamrai_FTE_CV.pdf
# 43  cv_to_df/Suchismita Mondal Dey_Resume_Airbus.pdf
# 44                  cv_to_df/Tanvir_s Resume (3).pdf
#
#                                                   All
# 0   AKASH SHAWBE in INFORMATION TECHNOLOGY@ akashs...
# 1   AKSHUN KHAJURIAEmail: akshun.khaj2002@gmail.co...
# 2
# 3   ANURAG KHURANAEmail: anuragkhurana2525@gmail.c...
# 4   Arghadeep Mukherjee (cid:131) +91-7439693606Ro...
# 5   ARGHYADIP ROYCONTACTEmail: agandpian2012@gmail...
# 6   Arindam HazraBachelor of Engineering +91-62903...
# 7   Arjun SaibyaJadavpur, Kolkata, WB9064471045 | ...
# 8   ASHWANI KUMAR@ ashwanibhagat2002@gmail.com # J...
# 9   AYAN MALBACHELOR OF MECHANICAL ENGINEERINGJADA...
# 10  Ayush ashPrak Ayush865 j (cid:239) ash-2bb6512...
# 11  GREGORY N. HOFFMAN3296 Elena Court (cid:25) Sa...
# 12  eMatthew WinstonMatthew WinstonIT Support Hist...
# 13  ePatricia L. Richardson768 Columbia DrivePortl...
# 14  eCraig Novak ConsultingClient  2Wire Inc. July...
# 15  eJohn Dawson429 Market StreetElmwood Park, NJ ...
# 16  eWilliam B. Stromfeld_________________________...
# 17  Baibhav Karan SinghStudentAn Engineering stude...
# 18  AVINANDA CHAKRABORTY  CONTACT@avinanda1303@gma...
# 19  6291853074DDeebbjjiitt DDaassdebjit.das.1729@g...
# 20  EDUCATIONB.E. in Electronics and Telecommunica...
# 21  HIMESH DUTTABachelor of Engineering +91-850938...
# 22  ISHITA BHATTACHARYYABachelor of Engineering +9...
# 23  Kunal PramanickProfile ContactI am an aspiring...
# 24  Muhsin Mansoor (cid:131) +91-9906008467Roll No...
# 25  Nilarghya Roynilportfolio.onrender.comroynilar...
# 26  Projna Sadhukhan+91-7980656376Roll No.:0020108...
# 27  Rajan Kumar MahatoAbout MeAn undergraduate stu...
# 28  R A Y A A N G H O S HM E C H A N I C A L E N G...
# 29  avraneelpal22@gmail.comAvraneel Pal9836489177g...
# 30  SAMPREETI BISWASE-mail: iva.teghoria@gmail.com...
# 31  Aritra SahaKolkata, West Bengal(cid:131) +91 6...
# 32  PERSONAL INFODeepanjan DasNationality:IndianLi...
# 33  MD NASIRUDDIN(+91) 8167715678 | mdnasir.suri@g...
# 34  (cid:0)6(cid:0)D(cid:0)E(cid:0)D(cid:0)U(cid:0...
# 35  Rinku DasB.E. ProdE'24 at Jadavpur UniversityI...
# 36  RUDRAPRASAD ROYCoding EnthusiastProgrammer Wit...
# 37  Sabnam LaskarSoftware DeveloperStrong in desig...
# 38  SAIKAT M A Z U M D A R+91-8584091792 saikatmaz...
# 39  Shilpa MondalLINKEDIN.COM/IN/SHILPA-MONDAL-971...
# 40  Shlok JhunjhunwalaBachelor of Engineering +91-...
# 41  Sikha Saha (cid:131) +91-7439463853Registratio...
# 42  Soumyadeep KhamraiEmail Id  soumyadeepkhamrai@...
# 43  RESUMECONTACT DETAILS:NAME - Suchismita Mondal...
# 44  Tanvir Alam tanviralam15p@gmail.comCSE,Jadavpu...

# %%
merged_df.columns
# Out:
# Index(['name', 'email', 'mobile_number', 'skills', 'degree', 'no_of_pages',
#        'file_path', 'All'],
#       dtype='object')

# %%
# df2 = merged_df.copy()

# %%
merged_df.to_csv('cv.csv')

# %%
df=pd.read_csv("cv.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                 name                          email  \
# 0           0           AKASH SHAW        akashshawju12@gmail.com
# 1           1      AKSHUN KHAJURIA      akshun.khaj2002@gmail.com
# 2           2                  NaN                            NaN
# 3           3       ANURAG KHURANA    anuragkhurana2525@gmail.com
# 4           4  Arghadeep Mukherjee  arghadeepischatting@gmail.com
#
#   mobile_number                                             skills  \
# 0    6290912977  ['Html5', 'Writing', 'System', 'Information te...
# 1    8899692356  ['System', 'Content', 'Email', 'Video', 'Micro...
# 2           NaN                                                 []
# 3    7889861541  ['System', 'Email', 'Microsoft word', 'Autocad...
# 4    0020112011  ['Video', 'Mechanical engineering', 'Autocad',...
#
#                                               degree  no_of_pages  \
# 0  ['WBBSE ( class X )', 'BE in INFORMATION TECHN...            1
# 1                   ['B.E. Mechanical Engineering)']            1
# 2                                               None            1
# 3                                               None            1
# 4                                               None            2
#
#                                           file_path  \
# 0                    cv_to_df/Akash_Shaw_resume.pdf
# 1               cv_to_df/AKSHUN_KHAJURIA_FTE_CV.pdf
# 2  cv_to_df/AnubhabTripathi_JadavpurUniversity1.pdf
# 3                  cv_to_df/Anurag Khurana_CV-3.pdf
# 4                  cv_to_df/Arghadeep-Mukherjee.pdf
#
#                                                  All
# 0  AKASH SHAWBE in INFORMATION TECHNOLOGY@ akashs...
# 1  AKSHUN KHAJURIAEmail: akshun.khaj2002@gmail.co...
# 2                                                NaN
# 3  ANURAG KHURANAEmail: anuragkhurana2525@gmail.c...
# 4  Arghadeep Mukherjee (cid:131) +91-7439693606Ro...

# %%
import os
import pandas as pd
from pyresparser import ResumeParser
import pdfplumber
import re

# %%
def pdf_to_base64(file_path):
    #with pdfplumber.open(filepath) as pdf
    with open(file_path, 'rb') as f:
    
        encoded_pdf = base64.b64encode(f.read()).decode('utf-8')

    return encoded_pdf

# %%
encoded_files=[]
for i in df["file_path"].values:
    print()
    encoded_files.append(pdf_to_base64(i))

# %%
df["pdf_to_base64"]=encoded_files

# %%
df.to_csv("updated_cv.csv",index=False)
